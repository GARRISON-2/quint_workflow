# %% [markdown]
# # Quint workflow

# %% [markdown]
# To use a custom reference image, need to use the packer from: https://github.com/Neural-Systems-at-UIO/QuickNII-extras

# %% [markdown]
# ## Step 0 - Program setup

# %%
#import PyNutil 
from pathlib import Path
import subprocess
from PIL import Image
import gc

# grab current working directory
PROJ_ROOT = Path.cwd()

dir24 = "/Xenium/TBI 24hrs"
dir48 = "/Xenium/TBI 48hrs"
dir48_MH2 = "/Xenium/TBI 48hrs + MH2"

png_output_dir =  PROJ_ROOT / "local_data" / "dapi_run_1" / "pngs"

mask_dir = PROJ_ROOT 
atlas_dir = PROJ_ROOT
out_dir = PROJ_ROOT

# %%
# # Grabbing input folders/files
# folder_list = []

# # set which image file type to search for in the directory
# file_type = "*.tif"

# for folder in folder_list:

#     # grab all files of file_type in chosen input directory
#     path_list = in_dir.rglob(file_type)


# test on specific file
path_list = [Path("")]

# %% [markdown]
# ## Step 1 - PNG Descaling

# %% [markdown]
# Images must be first scaled down to a 1500x1000 png file. (QuickNII can technically handle png or jpeg images of 16 megapixels, but there is no benefit to loading an image area more than 1500x1000 on most standard displays)

# %%
class IMG_PACK():
    def __init__(self, image_path):
        self.in_path = image_path
        self.png_path = None

    def makePNGCopy(self, output_dir, png_width = 1500, png_height=1000):
        # create png path name
        png_path = Path(str(output_dir) + self.in_path.stem + '_dwnscl')

        # open input image using Pillow
        try:
            with Image.open(self.in_path) as img:

                # resize image to desired ratio
                ds_img = img.resize((png_width, png_height))

                # convert to rgb and then save png copy of the input image. the original image remains unchanged
                ds_img.convert("RGB").save(png_path)
                self.png_path = png_path

        except Exception as e:
            return (f"ERROR - Unable to open image. {e}")
        

    def getPNGSize(self):
          # open input image using Pillow
        try:
            with Image.open(self.png_path) as png:

                return png.size

        except Exception as e:
            return (f"ERROR - Unable to open image. {e}")

# %%
check_img = True

IP_list = []

# loop through all input image files from glob list
for path in path_list:
#     # make image pack to cleanly hold paths for current file
    IP = IMG_PACK(path)

#     # create downscaled png copy
    IP.makePNGCopy(output_dir=png_output_dir)

    if check_img:
        with Image.open(IP.png_path) as png:
            print(f"New png path: {IP.png_path}. png size: {IP.getPNGSize()}")

    IP_list.append(IP)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\garyh\miniconda3\envs\quint_env\Lib\site-packages\PIL\Image.py:3437, in open(fp, mode, formats)
#    3436 try:
# -> 3437     fp.seek(0)
#    3438 except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'NoneType' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 14
#      11 IP.makePNGCopy(output_dir=png_output_dir)
#      13 if check_img:
# ---> 14     with Image.open(IP.png_path) as png:
#      15         print(f"New png path: {IP.png_path}. png size: {IP.getPNGSize()}")
#      17 IP_list.append(IP)
#
# File c:\Users\garyh\miniconda3\envs\quint_env\Lib\site-packages\PIL\Image.py:3439, in open(fp, mode, formats)
#    3437     fp.seek(0)
#    3438 except (AttributeError, io.UnsupportedOperation):
# -> 3439     fp = io.BytesIO(fp.read())
#    3440     exclusive_fp = True
#    3442 prefix = fp.read(16)
#
# AttributeError: 'NoneType' object has no attribute 'read'

# %% [markdown]
# ## Step 2 - QuickNII

# %% [markdown]
# Source code: https://github.com/Neural-Systems-at-UIO/QuickNII?tab=readme-ov-file

# %% [markdown]
# Open quint file bundler
#
# Run quint.exe
#
# Align mappings

# %% [markdown]
# ## Step 3 - VisuAlign

# %% [markdown]
# ## Step 4 - ilastik

# %% [markdown]
# ## Step 5 - Formatting for Nutil

# %%
from PIL import Image

# load png output from ilastik



#grab glasbey lookup table

# %% [markdown]
# ## Step 5 - Nutil
