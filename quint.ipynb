# %% [markdown]
# # Quint workflow

# %% [markdown]
# To use a custom reference image, need to use the packer from: https://github.com/Neural-Systems-at-UIO/QuickNII-extras

# %% [markdown]
# ## Step 0 - Program setup

# %%
import PyNutil 
from pathlib import Path
import subprocess
from PIL import Image
import gc

# grab current working directory
PROJ_ROOT = Path.cwd()

in_dir = PROJ_ROOT / 'local_data/test_folder/empty_tiffs'
mask_dir = PROJ_ROOT
atlas_dir = PROJ_ROOT
out_dir = PROJ_ROOT

# %% [markdown]
# ## For downloading test images

# %%
from allensdk.api.queries.image_download_api import ImageDownloadApi

img_api = ImageDownloadApi()

# This ID is for a specific mouse brain section (Nissl stain)
section_image_id = 70945123 

# 'downsample=3' makes the image a manageable size for testing
# (roughly 1/8th of full resolution)
img_api.download_section_image(section_image_id, 'test_brain_s001.jpg', downsample=3)

# %% [markdown]
# ## Step 1 - PNG Descaling

# %% [markdown]
# Images must be first scaled down to a 1500x1000 png file. (QuickNII can technically handle png or jpeg images of 16 megapixels, but there is no benefit to loading an image area more than 1500x1000 on most standard displays)

# %%
class IMG_PACK():
    def __init__(self, image_path):
        in_path = image_path
        png_path = None

    def makePNGCopy(self, png_width = 1500, png_height=1000):
        # create png path name
        png_path = self.in_path.with_name(self.in_path.stem + "_ds.png")

        # open input image using Pillow
        img = Image.open(self.in_path)

        # resize image to desired ratio
        ds_img = img.resize((png_width, png_height))

        # convert to rgb and then save png copy of the input image. the original image remains unchanged
        ds_img.convert("RGB").save(png_path)
        self.png_path = png_path

# %%
# set which image file type to seach for in the directory
file_type = "*.tif"

# grab all files of file_type in chosen input directory
path_list = in_dir.rglob(file_type)

# loop through all input image files from glob list
for path in path_list:
    # make image pack to cleanly hold paths for current file
    IP = IMG_PACK(path)

    # create downscaled png copy
    IP.makePNGCopy()

# %% [markdown]
# ## Step 2 - QuickNII

# %% [markdown]
# Source code: https://github.com/Neural-Systems-at-UIO/QuickNII?tab=readme-ov-file

# %% [markdown]
# Open quint file bundler
#
# Run quint.exe
#
# Align mappings

# %% [markdown]
# ## Step 3 - VisuAlign

# %% [markdown]
# ## Step 4 - ilastik

# %% [markdown]
# ## Step 5 - Formatting for Nutil

# %%
from PIL import Image
import numpy as np


#

# load png output from ilastik



#grab glasbey lookup table

# %% [markdown]
# ## Step 5 - Nutil
